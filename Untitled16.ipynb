# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/aula-IW/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

aluno = {
    "nome":"Lucas",
    "idade": 15,
    "curso": "Informatica"
}
print(aluno)
# Out:
# {'nome': 'Lucas', 'idade': 15, 'curso': 'Informatica'}

# %%
#2

aluno = {
    "nome": "Nalu",
    "idade": 17,
    "curso": "Química"
}
print("Nome:", aluno["nome"])
print("Idade:", aluno["idade"])
print("Curso:", aluno["curso"])
# Out:
# Nome: Nalu
# Idade: 17
# Curso: Química

# %%
#3

produto = {
    "nome": "Teclado",
    "preço": 150.0,
    "estoque": 10
}
produto["preço"] = 120.0
print(produto)
# Out:
# {'nome': 'Teclado', 'preço': 120.0, 'estoque': 10}

# %%
#4

aluno = {
    "nome": "Lucas",
    "idade": 16
}
aluno["curso"] = "Design"
print(aluno)
# Out:
# {'nome': 'Lucas', 'idade': 16, 'curso': 'Design'}

# %%
#5

filme = {
    "título": "Homem-Aranha: Um Novo Dia",
    "ano": 2026,
    "gênero": "Fantasia",
    "nota": 8.5
}
print("Título:", filme["título"])
print("Ano:", filme["ano"])
print("Gênero:", filme["gênero"])
print("Nota:", filme["nota"])
# Out:
# Título: Homem-Aranha: Um Novo Dia
# Ano: 2026
# Gênero: Fantasia
# Nota: 8.5

# %%
#1- conjuntos

numeros = {1, 2, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
#2- conjuntos

numeros = {1, 2, 2, 3, 3, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
#3- conjuntos

frutas = {"maçã", "banana", "laranja"}
frutas.add("morango")
print(frutas)
# Out:
# {'laranja', 'maçã', 'morango', 'banana'}

# %%
#4- conjunto

cores = {"vermelho", "azul", "verde", "amarelo"}
cores.remove("verde")
print(cores)
# Out:
# {'vermelho', 'azul', 'amarelo'}

# %%
#5- conjuntos

nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]
nomes_unicos =  set(nomes)
print(nomes_unicos)
# Out:
# {'Luna', 'Yris', 'Theo', 'Maitê', 'Gael', 'Ravi'}
