# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/aula-IW/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5 Solicite um número de 1 a 10 ao usuário e exiba a tabuada.

# %%
#6 Solicite ao usuário 4 notas e calcule a média.

# %%
#7 Crie um programa que solicite uma senha até que o usuário digite a senha correta.

# %%
#8 Faça um programa que receba valores e quantidade de produtos e no final exiba o valor total da compra.

# %%
#9 Peça ao usuário para digitar 5 números e no final exiba uma mensagem com maior número
