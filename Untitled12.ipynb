# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/aula-IW/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1

#CRIE AS VARIAVEIS USANDO PRINT E TYPE
#nome
#idade
#altura
#nota
#cidade

nome = str (input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
nota = float(input("Digite sua nota: "))
cidade = str(input("Digite sua cidade: "))

print(f"--------------------------------------")
print({type(nome)})
print(f"--------------------------------------")
print({type(idade)})
print(f"--------------------------------------")
print({type(altura)})
print(f"--------------------------------------")
print({type(nota)})
print(f"--------------------------------------")
print({type(cidade)})
print(f"--------------------------------------")
# Out:
# Digite seu nome: lucas
# Digite sua idade: 16
# Digite sua altura: 1.75
# Digite sua nota: 9
# Digite sua cidade: ribeirao pires
# --------------------------------------
# {<class 'str'>}
# --------------------------------------
# {<class 'int'>}
# --------------------------------------
# {<class 'float'>}
# --------------------------------------
# {<class 'float'>}
# --------------------------------------
# {<class 'str'>}
# --------------------------------------

# %%
#exercicio 2

#fazer um programa pra tirar a media das notas 6.5; 7.5; 8

nota1 =  6.5
nota2 =  7.5
nota3 =  8

notaf = (nota1 + nota2 + nota3) / 3
print (f"Sua média final é {notaf}")
# Out:
# Sua média final é 7.333333333333333

# %%
#exercicio 3
# faça as conversões e mostre os resultados

t1 = 20
t2 = 3.5
n = 8


t1 = int("20") + 10
print("O valor da variável t1 é: 30")

t2 = float("3.5") * 2
print("O valor da variável t2 é: 7")

n = str("8") + "anos"
print("O valor da variável n é: 8 anos")
# Out:
# O valor da variável t1 é: 30
# O valor da variável t2 é: 7
# O valor da variável n é: 8 anos

# %%
#exercicio 4

#expressoes aritmeticas

#calcule o valor de dobro de 15 e metade de 90

print ('O valor do dobro de 15:', 15 * 2)
print ('metade de 90:', 90 / 2)
print ('O resto da divisão de 17 por 5:', 17 % 5)
print ('2 elevados à potência 4:', 2 ** 4)
print ('A média de 10, 8 e 6:', (10 + 8 + 6 ) / 3)
# Out:
# O valor do dobro de 15: 30
# metade de 90: 45.0
# O resto da divisão de 17 por 5: 2
# 2 elevados à potência 4: 16
# A média de 10, 8 e 6: 8.0

# %%
#exercicio 5

#Comparações (relacionais)
#Mostre o resultado (True ou False) das comparações:

idade = 16
nota = 8.5
preço = 45.0

print('idade >= 18:',idade >= 18)
print("--------------------------")
print('nota > 7:', nota > 7)
print("--------------------------")
print('preço <= 50:', preço <= 50)
print("--------------------------")
print('idade == 16:', idade == 16)
print("--------------------------")
print('nota != 10:', nota != 10)
# Out:
# idade >= 18: False
# --------------------------
# nota > 7: True
# --------------------------
# preço <= 50: True
# --------------------------
# idade == 16: True
# --------------------------
# nota != 10: True

# %%
#Exercício 6

#Um produto custa R$ 80,00. O cliente ganhou 10% de desconto.
#Faça um programa que calcule e mostre:

#O valor do desconto
#O valor final a pagar
#Se o valor final é menor que 75.00 (True ou False)

preço_original = 80.0
desconto = preço_original * 0.1
preço_final = preço_original - desconto

print (" O valor do desconto é do desconto é R$", desconto)
print ("-----------------------------------------")
print ("o valor a ser pago será de R$", preço_final)
# Out:
#  O valor do desconto é do desconto é R$ 8.0
# -----------------------------------------
# o valor a ser pago será de R$ 72.0

# %%
#execicio 7

#Crie um programa que:

#Guarde o nome de um aluno
#Guarde duas notas
#Calcule a média
#Mostre uma frase assim: O aluno João tirou média 7.5

nome = str(input("Digite se nome: "))
n1 = float(input("Digite sua nota do 1° bimestre: "))
n2 = float(input("Digite sua nota do 2° bimestre: "))
media = (n1 + n2) / 2

print (f"a media final de {nome} é {media}")
# Out:
# Digite se nome: ruben
# Digite sua nota do 1° bimestre: 7
# Digite sua nota do 2° bimestre: 8
# a media final de ruben é 7.5
