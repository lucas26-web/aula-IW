# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/aula-IW/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 1 – Idade para dirigir

#Receba a idade de uma pessoa e diga se ela pode tirar carteira de motorista. A pessoa
#pode tirar a carteira se tiver idade maior ou igual a 18 anos.

idade = int(input("Digite sua idade: "))

if idade >= 18:
  print ("Cê pode dirigir guri, vaitimbora")

else:
  print ("Tá me tirando de louco é fih, se entope de feno zé")
# Out:
# Digite sua idade: 12
# Tá me tirando de louco é fih, se entope de feno zé

# %%
#Exercício 2 – Par ou Ímpar
#Receba um número e diga se ele é par ou ímpar

n = int(input("Digite um numero: "))

if n % 2 == 0:
  print ("valeu por aprender o básico de par pu impar, jumento...")

else:
  print("poh bichão, prefere ímpar mesmo? esquisito")
# Out:
# Digite um numero: 12
# valeu por aprender o básico de par pu impar, jumento...

# %%
#Exercício 3 – Maior de dois números
#Receba dois números e mostre qual é o maior. Se os dois números forem iguais, diga que eles são iguais.

n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

print("-----------------------------------------------------------------------")
if n1 > n2:
    print(f"O primeiro número ({n1}) é o maior!")

else:
    if n2 > n1:
        print(f"O segundo número ({n2}) é o maior!")

    else:
        print("Os dois números são IGUAIS!")
n
# Out:
# Digite o primeiro número: 35
# Digite o segundo número: 12
# -----------------------------------------------------------------------
# O primeiro número (35.0) é o maior!
# 12

# %%
# Exercício 4 – Situação do aluno


nota = float(input("Digite a nota do aluno: "))

print("-----------------------------------------------------------------------")
if nota >= 7:
    print("Olha só quem decidiu ser alguém na vida! parabens por fazer sua obrigação")

else:
    if nota >= 5:
        print("Misericordia... pelo menos dá pra ser alguma coisa né")

    else:
        print("Não serve nem pra fazer o minimo meu parceiro... se for chorar manda audio")
# Out:
# Digite a nota do aluno: 8
# -----------------------------------------------------------------------
# APROVADO

# %%
# Exercício 5 - Desconto na compra

valor_compra = float(input("Digite o valor da compra: R$ "))

if valor_compra >= 100:
    desconto = valor_compra * 0.10
    valor_final = valor_compra - desconto
    print(f"Desconto de 10% aplicado! Valor final: R$ {valor_final:.2f}")

else:
    print(f"Sem desconto. Valor final: R$ {valor_compra:.2f}")
# Out:
# Digite o valor da compra: R$ 190.50
# Desconto de 10% aplicado! Valor final: R$ 171.45

# %%
# Exercício 6 - Positivo, Negativo ou Zero

numero = float(input("Digite um número para começar a verificação: "))

print("-----------------------------------------------------------------------")
if numero > 0:
  print("O número é POSITIVO!")
else:
  if numero < 0:
    print("O número é NEGATIVO!")
  else:
    print("O número é ZERO")
# Out:
# Digite um número para começar a verificação: 34
# -----------------------------------------------------------------------
# O número é POSITIVO!

# %%
# Exercício 7 – Classificação de idade

idade = int(input("Digite a sua idade: "))

print("-----------------------------------------------------------------------")
if idade < 12:
  print("Classificação: CRIANÇA")

else:
  if idade <= 17:
    print("Classificação: ADOLESCENTE")

  else:
    if idade <= 59:
      print("Classificação: ADULTO")

    else:
      print("Classificação: IDOSO")
# Out:
# Digite a sua idade: 15
# -----------------------------------------------------------------------
# Classificação: ADOLESCENTE

# %%
# Exercício 8 – Média de duas notas

n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))


media = (n1 + n2) / 2

print("-----------------------------------------------------------------------")
if media >= 7:
  print(f"Média: {media: .1f} - APROVADO!")

else:
  print(f"Média: {media: .1f} - REPROVADO!")
# Out:
# Digite a primeira nota: 9
# Digite a segunda nota: 10
# -----------------------------------------------------------------------
# Média:  9.5 - APROVADO!

# %%
# Exercício 9 – Login simples

usuario = input("Usuário: ")
senha = input("Senha: ")

print("-----------------------------------------------------------------------")
if usuario == "RUBINHO" and senha == "1234":
  print("Login realizado com sucesso!")

else: print("Usuário ou senha incorretos.")
# Out:
# Usuário: pavanato
# Senha: 14183655
# -----------------------------------------------------------------------
# Usuário ou senha incorretos.

# %%
# Exercício 10 – Calculadora de IMC

peso = float(input("Digite o seu peso(em KG): "))
altura = float(input("Digite a sua altura (em metros): "))

imc = peso / (altura * altura)

print("-----------------------------------------------------------------------")
print(f"Seu IMC é: {imc: .2f}")

if imc < 18.5:
  print("pretende se deixar levar pela primeira rajada de vento filho?")

else:
  if imc <= 24.9:
    print("segue o baile campeão")

  else:
    if imc <= 29.9:
      print("tá chegando lá fih, continua")

    else:
      print("um pouquinho acima né colega...")
# Out:
# Digite o seu peso(em KG): 62.0
# Digite a sua altura (em metros): 1.76
# -----------------------------------------------------------------------
# Seu IMC é:  20.02
# segue o baile campeão
